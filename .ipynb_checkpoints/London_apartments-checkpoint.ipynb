# %%
import numpy as np
from rightmove_webscraper import RightmoveData
from IPython.display import display

# %% [markdown]
# Webscraper taken from https://github.com/toby-p/rightmove_webscraper.py

# %%
url = "https://www.rightmove.co.uk/property-to-rent/find.html?searchType=RENT&locationIdentifier=STATION%5E3431&insId=1&radius=5.0&minPrice=&maxPrice=&minBedrooms=&maxBedrooms=&displayPropertyType=flats&maxDaysSinceAdded=&sortByPriceDescending=&_includeLetAgreed=on&primaryDisplayPropertyType=&secondaryDisplayPropertyType=&oldDisplayPropertyType=&oldPrimaryDisplayPropertyType=&letType=&letFurnishType=&houseFlatShare="
rm = RightmoveData(url)

# %%
# Refresh data
rm.refresh_data()

# %%
# average price for the search
rm.average_price

# How many pages is the search result?
# rm.page_count

# Is the search for rental or sale?
# rm.rent_or_sale
# Out:
# 2231.9904761904763

# %%
# number of search results
rm.results_count
# Out:
# 1050

# %%
# Summary of results
display(rm.summary())

# summary of results, by postcode
display(rm.summary(by = "postcode").head())
# Out:
#    number_bedrooms  count         mean
# 0                0    113  1212.522124
# 1                1    353  1662.283286
# 2                2    389  2288.280206
# 3                3    149  3775.194631
# 4                4     37  3301.000000
# 5                5      7  8210.000000
#   postcode  count         mean
# 0       W2     67  2906.716418
# 1      E14     66  1690.530303
# 2       N1     38  1880.210526
# 3      NW3     35  1766.371429
# 4      W11     30  3322.866667

# %%
apartments_df = rm.get_results
apartments_df.head()
# Out:
#    price                 type  \
# 0   2253       2 bedroom flat
# 1   1150       1 bedroom flat
# 2   2448  1 bedroom apartment
# 3   2232  1 bedroom apartment
# 4   2665  2 bedroom apartment
#
#                                              address  \
# 0                         Apsley House, London, NW8
# 1                          Cricketfield Road, London
# 2                 Apartment ,  Casson Square, London
# 3  Amazing one bed in Cassia House,  Piazza Walk,...
# 4    Apartment , Catalina House,  Canter Way, London
#
#                                                  url  \
# 0  http://www.rightmove.co.uk/property-to-rent/pr...
# 1  http://www.rightmove.co.uk/property-to-rent/pr...
# 2  http://www.rightmove.co.uk/property-to-rent/pr...
# 3  http://www.rightmove.co.uk/property-to-rent/pr...
# 4  http://www.rightmove.co.uk/property-to-rent/pr...
#
#                                            agent_url postcode  \
# 0  http://www.rightmove.co.uk/estate-agents/agent...      NW8
# 1  http://www.rightmove.co.uk/estate-agents/agent...      NaN
# 2  http://www.rightmove.co.uk/estate-agents/agent...      NaN
# 3  http://www.rightmove.co.uk/estate-agents/agent...      NaN
# 4  http://www.rightmove.co.uk/estate-agents/agent...      NaN
#
#    number_bedrooms                search_date
# 0              2.0 2020-11-15 16:23:13.677061
# 1              1.0 2020-11-15 16:23:13.677061
# 2              1.0 2020-11-15 16:23:13.677061
# 3              1.0 2020-11-15 16:23:13.677061
# 4              2.0 2020-11-15 16:23:13.677061

# %%
apartments_df.type.value_counts().head()
# Out:
# 2 bedroom flat         220
# 1 bedroom flat         215
# 2 bedroom apartment    149
# 1 bedroom apartment    121
# Studio flat            102
# Name: type, dtype: int64

# %%
max_rent = 2000

apartments_df = apartments_df[apartments_df.price < max_rent]
display(apartments_df.head())

apartments_df.shape
# Out:
#     price                  type                       address  \
# 1    1150        1 bedroom flat     Cricketfield Road, London
# 6    1790        1 bedroom flat  De Beauvoir Cres, London, N1
# 7    1715        2 bedroom flat  Flannery Court, London, SE16
# 8     599  1 bedroom flat share     Arbour Square, London, E1
# 10    645  1 bedroom flat share    Jamaica Street, London, E1
#
#                                                   url  \
# 1   http://www.rightmove.co.uk/property-to-rent/pr...
# 6   http://www.rightmove.co.uk/property-to-rent/pr...
# 7   http://www.rightmove.co.uk/property-to-rent/pr...
# 8   http://www.rightmove.co.uk/property-to-rent/pr...
# 10  http://www.rightmove.co.uk/property-to-rent/pr...
#
#                                             agent_url postcode  \
# 1   http://www.rightmove.co.uk/estate-agents/agent...      NaN
# 6   http://www.rightmove.co.uk/estate-agents/agent...       N1
# 7   http://www.rightmove.co.uk/estate-agents/agent...     SE16
# 8   http://www.rightmove.co.uk/estate-agents/agent...       E1
# 10  http://www.rightmove.co.uk/estate-agents/agent...       E1
#
#     number_bedrooms                search_date
# 1               1.0 2020-11-15 16:23:13.677061
# 6               1.0 2020-11-15 16:23:13.677061
# 7               2.0 2020-11-15 16:23:13.677061
# 8               1.0 2020-11-15 16:23:13.677061
# 10              1.0 2020-11-15 16:23:13.677061
# (683, 8)

# %%
display(apartments_df.number_bedrooms.value_counts())

# There are no missing number of bedrooms, those are just studio flats! Remove them. 
display(apartments_df[apartments_df.number_bedrooms == 0].type.value_counts())

apartments_df = apartments_df[apartments_df.number_bedrooms != 0]
display(apartments_df.head())
# Out:
# 1.0    286
# 2.0    226
# 0.0    110
# 3.0     50
# 4.0      9
# 5.0      1
# Name: number_bedrooms, dtype: int64
# Studio flat         99
# Studio apartment    11
# Name: type, dtype: int64
#     price                  type                       address  \
# 1    1150        1 bedroom flat     Cricketfield Road, London
# 6    1790        1 bedroom flat  De Beauvoir Cres, London, N1
# 7    1715        2 bedroom flat  Flannery Court, London, SE16
# 8     599  1 bedroom flat share     Arbour Square, London, E1
# 10    645  1 bedroom flat share    Jamaica Street, London, E1
#
#                                                   url  \
# 1   http://www.rightmove.co.uk/property-to-rent/pr...
# 6   http://www.rightmove.co.uk/property-to-rent/pr...
# 7   http://www.rightmove.co.uk/property-to-rent/pr...
# 8   http://www.rightmove.co.uk/property-to-rent/pr...
# 10  http://www.rightmove.co.uk/property-to-rent/pr...
#
#                                             agent_url postcode  \
# 1   http://www.rightmove.co.uk/estate-agents/agent...      NaN
# 6   http://www.rightmove.co.uk/estate-agents/agent...       N1
# 7   http://www.rightmove.co.uk/estate-agents/agent...     SE16
# 8   http://www.rightmove.co.uk/estate-agents/agent...       E1
# 10  http://www.rightmove.co.uk/estate-agents/agent...       E1
#
#     number_bedrooms                search_date
# 1               1.0 2020-11-15 16:23:13.677061
# 6               1.0 2020-11-15 16:23:13.677061
# 7               2.0 2020-11-15 16:23:13.677061
# 8               1.0 2020-11-15 16:23:13.677061
# 10              1.0 2020-11-15 16:23:13.677061
